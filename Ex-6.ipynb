# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Set a random seed for reproducibility
np.random.seed(42)

# Create a simple dataset
data = {
    'Feature1': np.random.rand(100),  # Feature 1 (continuous)
    'Feature2': np.random.rand(100),  # Feature 2 (continuous)
    'Target': np.random.choice([0, 1], size=100)  # Binary target variable
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the dataset
print(df.head())

# Split the dataset into features (X) and target variable (y)
X = df[['Feature1', 'Feature2']]
y = df['Target']

# Split the dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf = clf.fit(X_train, y_train)

# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=['0', '1'], filled=True, rounded=True)
plt.show()
# Out:
#    Feature1  Feature2  Target
# 0  0.374540  0.031429       1
# 1  0.950714  0.636410       1
# 2  0.731994  0.314356       0
# 3  0.598658  0.508571       0
# 4  0.156019  0.907566       1

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Color': ['Red', 'Red', 'Yellow', 'Blue', 'Red', 'Yellow', 'Red'],
    'Model_Year': [2012, 2009, 2015, 2018, 2011, 2019, 2002],
    'Mileage': [40000, 60000, 30000, 80000, 55000, 20000, 49000],
    'Model': ['Ferrari', 'Toyota', 'Ferrari', 'Ford', 'Honda', 'Tesla', 'Ferrari'],
    'Buy': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes']
}

df = pd.DataFrame(data)

# Convert categorical variables to numerical
df['Color'] = df['Color'].map({'Red': 1, 'Yellow': 2, 'Blue': 3})
df['Buy'] = df['Buy'].map({'Yes': 1, 'No': 0})
df['Model'] = df['Model'].apply(lambda x: 1 if x == 'Ferrari' else 0)

# Features and target variable
X = df[['Color', 'Model_Year', 'Mileage', 'Model']]
y = df['Buy']

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf = clf.fit(X, y)

# Plot the decision tree
plt.figure(figsize=(15, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True, rounded=True)
plt.show()

# %%
data = pd.read_csv('cars.csv')
df = pd.DataFrame(data)

# Convert categorical variables to numerical
df['Color'] = df['Color'].map({'Red': 1, 'Yellow': 2, 'Blue': 3})
df['Buy'] = df['Buy'].map({'Yes': 1, 'No': 0})
df['Model'] = df['Model'].apply(lambda x: 1 if x == 'Ferrari' else 0)

# Features and target variable
X = df[['Color', 'Model_Year', 'Mileage', 'Model']]
y = df['Buy']

# Create Decision Tree classifier object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifier
clf = clf.fit(X, y)

# Plot the decision tree
plt.figure(figsize=(10, 8))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True, rounded=True)
plt.show()
